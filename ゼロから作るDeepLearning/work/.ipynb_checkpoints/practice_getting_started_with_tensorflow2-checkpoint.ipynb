# %% [markdown]
# # Getting started with TensorFlow 2(Coursera)

# %% [markdown]
# ## ーーーーーーーーーーーーー
# ## Week 2 The Sequential model API

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
tf.__version__
# Out:
# '2.4.1'

# %%
from tensorflow.keras.models import  Sequential
from tensorflow.keras.layers import Dense, Flatten

# Sequentialモデルを生成する
model = Sequential([
    Flatten(input_shape=(28,28)),
    Dense(64, activation='relu')
])

# model.add(Dense(64, activation='relu')) のようにレイヤを追加することもできる

# %%
# モデルのサマリ確認
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                50240
# ...
# Total params: 50,240
# Trainable params: 50,240
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.layers import Conv2D, MaxPooling2D

model = Sequential([
    # 16枚,3*3のフィルタを用意する
    # padding='same'にすることにより,出力が入力と同サイズになることがsummaryから確認できる
    Conv2D(16, (3,3), activation='relu', input_shape=(28, 28, 1)),
    MaxPooling2D((3,3)),
    Flatten(),
    Dense(10, activation='softmax')
])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d (Conv2D)              (None, 26, 26, 16)        160
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 8, 8, 16)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                10250
# ...
# Total params: 10,410
# Trainable params: 10,410
# Non-trainable params: 0
# _________________________________________________________________

# %%
# w,bの初期値も引数で設定できる
# model.add(Dense(64,
#                kernel_initializer=tf.keras.initializers.RandomNormal(mean=0.0, stddev=0.05),
#                bias_initializer=tf.keras.initializers.Constant(value=0.4),
#                activation='relu'))

# %%
# model.add(Dense(1, activation='sigmoid'))

model.compile(
    optimizer=tf.optimizers.SGD(learning_rate=0.01),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# attributeとして確認
print(model.loss)
print(model.optimizer)
print(model.optimizer.lr)
print(model.metrics)
# Out:
# sparse_categorical_crossentropy
# ...
# <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.01>
# []

# %%
fashion_mnist_data = tf.keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_mnist_data.load_data()

print(train_images.shape)
print(train_labels.shape)
print(test_images.shape)
print(test_labels.shape)
# Out:
# (60000, 28, 28)
# (60000,)
# (10000, 28, 28)
# (10000,)

# %%
train_images = train_images/255.
test_images = test_images/255.

# %%
plt.imshow(train_images[0,:,:])

# %%
# x_train: num_samples, num_features
# train_imagesに行っている処理はチャンネル分の軸を１チャンネルとして足している
history = model.fit(train_images[...,np.newaxis], train_labels, epochs=8, batch_size=64)
# Out:
# Epoch 1/8
# 938/938 [==============================] - 7s 7ms/step - loss: 1.4052 - accuracy: 0.5418
# Epoch 2/8
# 938/938 [==============================] - 7s 7ms/step - loss: 0.6471 - accuracy: 0.7670
# Epoch 3/8
# 938/938 [==============================] - 7s 7ms/step - loss: 0.5759 - accuracy: 0.7883
# Epoch 4/8
# 938/938 [==============================] - 7s 7ms/step - loss: 0.5447 - accuracy: 0.8016
# Epoch 5/8
# 938/938 [==============================] - 6s 7ms/step - loss: 0.5148 - accuracy: 0.8136
# Epoch 6/8
# 938/938 [==============================] - 7s 7ms/step - loss: 0.4956 - accuracy: 0.8220
# Epoch 7/8
# 938/938 [==============================] - 7s 7ms/step - loss: 0.4782 - accuracy: 0.8318
# Epoch 8/8
# 938/938 [==============================] - 7s 7ms/step - loss: 0.4563 - accuracy: 0.8389

# %%
# historyに渡すことでエポックごとの結果が見れる
df = pd.DataFrame(history.history)
df.head()
# Out:
#        loss  accuracy
# 0  1.001006  0.664317
# 1  0.626753  0.772633
# 2  0.570828  0.791683
# 3  0.538575  0.802533
# 4  0.513220  0.814717

# %%
loss_plot = df.plot(y = 'loss')

# %%
# loss, accuracyの出力
model.evaluate(train_images[...,np.newaxis], train_labels)
# Out:
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4571 - accuracy: 0.8375
# [0.4571313261985779, 0.8374666571617126]

# %%
model.predict(test_images[...,np.newaxis])
# Out:
# array([[1.5748281e-05, 4.1032827e-06, 1.0655353e-05, ..., 2.0522413e-01,
#         1.0160901e-02, 7.5489390e-01],
#        [1.7528322e-03, 2.4369883e-05, 9.2967129e-01, ..., 2.1396182e-11,
#         4.1181012e-04, 6.8466277e-09],
#        [7.9605325e-06, 9.9991024e-01, 2.8311877e-07, ..., 1.2676673e-08,
#         7.4088211e-07, 1.5138098e-10],
#        ...,
#        [1.0808220e-01, 1.4562113e-05, 6.0796542e-03, ..., 3.4637455e-04,
#         7.1782321e-01, 8.7295684e-06],
#        [8.4689818e-06, 9.9733680e-01, 2.0087414e-06, ..., 5.5568862e-06,
#         3.6328111e-05, 1.0869695e-06],
#        [1.5968639e-04, 9.6263131e-05, 1.0683384e-03, ..., 1.4304142e-01,
#         1.6257497e-02, 2.9230420e-03]], dtype=float32)

# %% [markdown]
# ## ーーーーーーーーーーーーー
# ## week 3 - Validation, regularisation and callbacks

# %%
from sklearn.datasets import load_diabetes
diabetes_dataset = load_diabetes()
data = diabetes_dataset['data']
target = diabetes_dataset['target']

target = (target - target.mean(axis=0)/target.std())

# %%
# データを分割する
from sklearn.model_selection import train_test_split
train_data, test_data, train_target, test_target = train_test_split(data, target, test_size=0.1)

# %%
# make simple model

model = Sequential()
model.add(Dense(128, activation='relu', input_shape=(train_data.shape[1],)))
model.add(Dense(126, activation='relu'))
model.add(Dense(1))

opt = tf.keras.optimizers.Adam(learning_rate=0.05)
model.compile(optimizer=opt, loss='mse', metrics=['mae'])

# %%
epoch = 10
history = model.fit(train_data, train_target, epochs=epoch,
                   validation_split=0.15, batch_size=512, verbose=False)

# %%
model.evaluate(test_data, test_target)
# Out:
# 2/2 [==============================] - 0s 2ms/step - loss: 6611.6875 - mae: 66.4199
# [6611.6875, 66.41989135742188]

# %%
plt.plot(range(1,epoch+1), history.history['mae'])
plt.plot(range(1,epoch+1), history.history['val_mae'])

# %%
# 過学習を防ぐ仕組み(L2正則化,ドロップアウト)を入れる
from tensorflow.keras.layers import Dropout
from tensorflow.keras import regularizers

def get_regularised_model(wd, rate):
    model = Sequential([
        Dense(128, kernel_regularizer=regularizers.l2(wd), activation='relu'),
        Dropout(rate),
        Dense(128, kernel_regularizer=regularizers.l2(wd), activation='relu'),
        Dropout(rate),
        Dense(1)
    ])
    
    return model

model = get_regularised_model(1e-5, 0.3)

# %%
model.compile(optimizer='adam', loss='mse', metrics=['mae'])

# %%
history = model.fit(train_data, train_target, epochs=100,
                   validation_split=0.15, batch_size=128, verbose=False)

# %%
model.evaluate(test_data, test_target)
# Out:
# 2/2 [==============================] - 0s 3ms/step - loss: 3289.5627 - mae: 48.3523
# [3289.562744140625, 48.35234451293945]

# %%
plt.plot(range(1,100+1), history.history['mae'])
plt.plot(range(1,100+1), history.history['val_mae'])

# %%
# コールバック関数で出力を制御してみる
from tensorflow.keras.callbacks import  Callback

class TrainingCallback(Callback):
    
    def on_train_begin(self, logs=None):
        print("start training..")
        
    def on_epoch_begin(self, epoch, logs=None):
        print(f"start epoch {epoch}")
        
    def on_train_batch_begin(self, batch, logs=None):
        print(f"training: starting batch {batch}")
        
    def on_train_batch_end(self, batch, logs=None):
        print(f"training: finished batch {batch}")
        
    def on_epoch_end(self, epoch, logs=None):
        print(f"finish epoch {epoch}")
        
    def on_train_end(self, logs=None):
        print('finish training..')
        
class TestCallback(Callback):
    
    def on_test_begin(self, logs=None):
        print("start testing..")
        
    def on_test_batch_begin(self, batch, logs=None):
        print(f"testing: starting batch {batch}")
        
    def on_test_batch_end(self, batch, logs=None):
        print(f"testing: finished batch {batch}")
        
    def on_test_end(self, logs=None):
        print('finish testing..')
        
class PredictCallback(Callback):
    
    def on_predict_begin(self, logs=None):
        print("start predicting..")
        
    def on_predict_batch_begin(self, batch, logs=None):
        print(f"predicting: starting batch {batch}")
        
    def on_predict_batch_end(self, batch, logs=None):
        print(f"predicting: finished batch {batch}")
        
    def on_predict_end(self, logs=None):
        print('finish predicting..')

# %%
model = get_regularised_model(1e-5, 0.3)
model.compile(optimizer='adam', loss='mae')

# %%
model.fit(train_data, train_target, epochs=3, batch_size=128,
         verbose=False, callbacks=[TrainingCallback()])
# Out:
# start training..
# start epoch 0
# training: starting batch 0
# training: finished batch 0
# training: starting batch 1
# training: finished batch 1
# training: starting batch 2
# training: finished batch 2
# training: starting batch 3
# training: finished batch 3
# finish epoch 0
# start epoch 1
# training: starting batch 0
# training: finished batch 0
# training: starting batch 1
# training: finished batch 1
# training: starting batch 2
# training: finished batch 2
# training: starting batch 3
# training: finished batch 3
# finish epoch 1
# start epoch 2
# training: starting batch 0
# training: finished batch 0
# training: starting batch 1
# training: finished batch 1
# training: starting batch 2
# training: finished batch 2
# training: starting batch 3
# training: finished batch 3
# finish epoch 2
# finish training..

# %%
model.evaluate(test_data, test_target, verbose=False, callbacks=[TestCallback()])
# Out:
# start testing..
# testing: starting batch 0
# testing: finished batch 0
# testing: starting batch 1
# testing: finished batch 1
# finish testing..
# 152.83383178710938

# %%
model.predict(test_data, verbose=False, callbacks=[PredictCallback()])
# Out:
# start predicting..
# predicting: starting batch 0
# predicting: finished batch 0
# predicting: starting batch 1
# predicting: finished batch 1
# finish predicting..
# array([[0.31552792],
#        [0.25129378],
#        [0.36380678],
#        [0.32523435],
#        [0.27924466],
#        [0.28513956],
#        [0.28147608],
#        [0.30444795],
#        [0.38035566],
#        [0.28807285],
#        [0.26246282],
#        [0.2840289 ],
#        [0.33257496],
#        [0.40829217],
#        [0.35833475],
#        [0.29752582],
#        [0.26417682],
#        [0.31410688],
#        [0.26198965],
#        [0.25958434],
#        [0.26808006],
#        [0.26343772],
#        [0.29624236],
#        [0.33784795],
#        [0.28292328],
#        [0.28179187],
#        [0.30578375],
#        [0.30152223],
#        [0.36317837],
#        [0.30660933],
#        [0.28277665],
#        [0.34158504],
#        [0.2875025 ],
#        [0.3411782 ],
#        [0.25789192],
#        [0.27932656],
# ...

# %%
def get_model():
    model = Sequential([
        Dense(128, activation='relu'),
        Dense(128, activation='relu'),
        Dense(1)
    ])
    
    return model


unregularised_model = get_model()
unregularised_model.compile(optimizer='adam', loss='mse')
unreg_history = unregularised_model.fit(train_data, train_target, epochs=100,
                                       validation_split=0.15, batch_size=64,
                                       verbose=False, callbacks=[tf.keras.callbacks.EarlyStopping()])

# %%
unregularised_model.evaluate(test_data, test_target, verbose=2)
# Out:
# 2/2 - 0s - loss: 3046.2229
# 3046.222900390625

# %%
regularided_model = get_regularised_model(1e-8, 0.2)
regularided_model.compile(optimizer='adam', loss='mse')
reg_history = unregularised_model.fit(train_data, train_target, epochs=100,
                                       validation_split=0.15, batch_size=64,
                                       verbose=False, callbacks=[tf.keras.callbacks.EarlyStopping()])

# %%
regularided_model.evaluate(test_data, test_target, verbose=2)
# Out:
# 2/2 - 0s - loss: 30036.4863
# 30036.486328125

# %%
plt.plot(unreg_history.history['loss'])
plt.plot(unreg_history.history['val_loss'])

# %%
unreg_history.history.keys()
# Out:
# dict_keys(['loss', 'val_loss'])

# %% [markdown]
# ## ーーーーーーーーーーーーー
# ## week 4 - Saving and loading models

# %%
# Import the CIFAR-10 dataset and rescale the pixel values

(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()
x_train = x_train / 255.0
x_test = x_test / 255.0

# Use smaller subset -- speeds things up
x_train = x_train[:10000]
y_train = y_train[:10000]
x_test = x_test[:1000]
y_test = y_test[:1000]

# %%
# Introduce function to test model accuracy

def get_test_accuracy(model, x_test, y_test):
    test_loss, test_acc = model.evaluate(x=x_test, y=y_test, verbose=0)
    print('accuracy: {acc:0.3f}'.format(acc=test_acc))
    
    
# Introduce function that creates a new instance of a simple CNN

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D

def get_new_model():
    model = Sequential([
        Conv2D(filters=16, input_shape=(32, 32, 3), kernel_size=(3, 3), 
               activation='relu', name='conv_1'),
        Conv2D(filters=8, kernel_size=(3, 3), activation='relu', name='conv_2'),
        MaxPooling2D(pool_size=(4, 4), name='pool_1'),
        Flatten(name='flatten'),
        Dense(units=32, activation='relu', name='dense_1'),
        Dense(units=10, activation='softmax', name='dense_2')
    ])
    model.compile(optimizer='adam',
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    return model

# %%
model = get_new_model()
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv_1 (Conv2D)              (None, 30, 30, 16)        448
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 28, 28, 8)         1160
# _________________________________________________________________
# pool_1 (MaxPooling2D)        (None, 7, 7, 8)           0
# _________________________________________________________________
# flatten (Flatten)            (None, 392)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                12576
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                330
# ...
# Total params: 14,514
# Trainable params: 14,514
# Non-trainable params: 0
# ...

# %%
get_test_accuracy(model, x_test, y_test)
# Out:
# accuracy: 0.083

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

checkpoint_path = 'model_checkpoints/checkpoint'
checkpoint = ModelCheckpoint(filepath = checkpoint_path,
                            frequency = 'epoch',
                            save_weights_only=True,
                            verbose = 1)

# %%
model.fit(x=x_train, y=y_train, epochs=3, callbacks=[checkpoint])
# Out:
# Epoch 1/3
# 313/313 [==============================] - 4s 12ms/step - loss: 1.9728 - accuracy: 0.2797
#
# Epoch 00001: saving model to model_checkpoints/checkpoint
# Epoch 2/3
# 313/313 [==============================] - 4s 12ms/step - loss: 1.6075 - accuracy: 0.4182
#
# Epoch 00002: saving model to model_checkpoints/checkpoint
# Epoch 3/3
# 313/313 [==============================] - 4s 12ms/step - loss: 1.4643 - accuracy: 0.4702
#
# Epoch 00003: saving model to model_checkpoints/checkpoint

# %%
! ls model_checkpoints/
# Out:
# checkpoint  checkpoint.data-00000-of-00001  checkpoint.index

# %%
get_test_accuracy(model, x_test, y_test)
# Out:
# accuracy: 0.454

# %%
model = get_new_model()
get_test_accuracy(model, x_test, y_test)
# Out:
# accuracy: 0.080

# %%
# 先ほど保存しておいたcheckpointをロードできていることが確認できる
model.load_weights(checkpoint_path)
get_test_accuracy(model, x_test, y_test)
# Out:
# accuracy: 0.454

# %%
checkpoint_5000_path = \
    'model_checkpoints_5000/checkpoint_{epoch:02d}_{batch:04d}'
checkpoint_5000 = ModelCheckpoint(filepath=checkpoint_5000_path,
                                 save_weights_only=True,
                                 save_freq=5000,
                                 verbose=1)

# %%
model = get_new_model()
model.fit(x=x_train, y=y_train, epochs=3,
         validation_data=(x_test, y_test),
         batch_size=10,callbacks=[checkpoint_5000])
# Out:
# Epoch 1/3
# 1000/1000 [==============================] - 8s 7ms/step - loss: 2.0703 - accuracy: 0.2264 - val_loss: 1.6784 - val_accuracy: 0.3990
# Epoch 2/3
# 1000/1000 [==============================] - 7s 7ms/step - loss: 1.6060 - accuracy: 0.4127 - val_loss: 1.5313 - val_accuracy: 0.4450
# Epoch 3/3
# 1000/1000 [==============================] - 7s 7ms/step - loss: 1.5077 - accuracy: 0.4483 - val_loss: 1.5348 - val_accuracy: 0.4730

# %%
checkpoint_path = 'model_checkpoints'
checkpoint = ModelCheckpoint(filepath=checkpoint_path,
                            save_weights_only=False,
                            frequency='epoch',
                            verbose=1)

# %%
model = get_new_model()
model.fit(x_train, y_train, epochs=3, callbacks=[checkpoint])
# Out:
# Epoch 1/3
# 313/313 [==============================] - 4s 13ms/step - loss: 2.1020 - accuracy: 0.2104
#
# Epoch 00001: saving model to model_checkpoints
# INFO:tensorflow:Assets written to: model_checkpoints/assets
# Epoch 2/3
# 313/313 [==============================] - 4s 13ms/step - loss: 1.6330 - accuracy: 0.4051
#
# Epoch 00002: saving model to model_checkpoints
# INFO:tensorflow:Assets written to: model_checkpoints/assets
# Epoch 3/3
# 313/313 [==============================] - 4s 13ms/step - loss: 1.4959 - accuracy: 0.4624
#
# Epoch 00003: saving model to model_checkpoints
# INFO:tensorflow:Assets written to: model_checkpoints/assets

# %%
! ls model_checkpoints/
# Out:
# assets	    checkpoint.data-00000-of-00001  saved_model.pb
# checkpoint  checkpoint.index		    variables

# %%
# 一度model変数を初期化しても、loadできることが確認できる
del model

from tensorflow.keras.models import load_model
model = load_model(checkpoint_path)
get_test_accuracy(model, x_test, y_test)
# Out:
# accuracy: 0.463

# %%
# h5形式でも保存、ロードができる
model.save('my_model.h5')

del model

model = load_model('my_model.h5')
get_test_accuracy(model, x_test, y_test)
# Out:
# accuracy: 0.463

# %%
# imagenetで学習済みの重みデータを使用したResNetモデルを読み込む
from tensorflow.keras.applications import ResNet50
model = ResNet50(weights='imagenet')
model.summary()
# Out:
# Model: "resnet50"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_2 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 230, 230, 3)  0           input_2[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 112, 112, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 112, 112, 64) 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 112, 112, 64) 0           conv1_bn[0][0]
# ...
